# %% [markdown]
# <a href="https://colab.research.google.com/github/hsallrounder/Application-Of-Machine-Learning-In-Industries-Workshop-2023/blob/main/TSLA_Application_Of_Machine_Learning_In_Industries_Workshop_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/Datasets/TSLA.csv')

# %%
data.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 1  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 3  2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 4  2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2392 non-null   object
#  1   Open       2392 non-null   float64
#  2   High       2392 non-null   float64
#  3   Low        2392 non-null   float64
#  4   Close      2392 non-null   float64
#  5   Adj Close  2392 non-null   float64
#  6   Volume     2392 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 130.9+ KB

# %%
label_encoder = preprocessing.LabelEncoder()
data['Date'] = label_encoder.fit_transform(data['Date'])

# %%
scaler = preprocessing.MinMaxScaler()
data=scaler.fit_transform(data.drop(columns='Date'))

# %%
data=pd.DataFrame(data)
data
# Out:
#              0         1         2         3         4         5
# 0     0.021153  0.022189  0.012859  0.014838  0.014838  0.218659
# 1     0.016378  0.015453  0.009067  0.008190  0.008190  0.135544
# 2     0.009215  0.008049  0.002066  0.000747  0.000747  0.182166
# 3     0.000621  0.000000  0.000000  0.000000  0.000000  0.183645
# 4     0.000000  0.002126  0.001434  0.003999  0.003999  0.204962
# ...        ...       ...       ...       ...       ...       ...
# 2387  0.960273  0.976498  0.966794  0.986294  0.986294  0.214229
# 2388  0.983073  0.995629  1.000000  1.000000  1.000000  0.283852
# 2389  1.000000  1.000000  0.999417  0.998651  0.998651  0.265275
# 2390  0.985174  0.984929  0.958456  0.960881  0.960881  0.336557
# 2391  0.928377  0.966514  0.941002  0.969625  0.969625  0.274452
#
# [2392 rows x 6 columns]

# %%
data
# Out:
#              0         1         2         3         4         5
# 0     0.021153  0.022189  0.012859  0.014838  0.014838  0.218659
# 1     0.016378  0.015453  0.009067  0.008190  0.008190  0.135544
# 2     0.009215  0.008049  0.002066  0.000747  0.000747  0.182166
# 3     0.000621  0.000000  0.000000  0.000000  0.000000  0.183645
# 4     0.000000  0.002126  0.001434  0.003999  0.003999  0.204962
# ...        ...       ...       ...       ...       ...       ...
# 2387  0.960273  0.976498  0.966794  0.986294  0.986294  0.214229
# 2388  0.983073  0.995629  1.000000  1.000000  1.000000  0.283852
# 2389  1.000000  1.000000  0.999417  0.998651  0.998651  0.265275
# 2390  0.985174  0.984929  0.958456  0.960881  0.960881  0.336557
# 2391  0.928377  0.966514  0.941002  0.969625  0.969625  0.274452
#
# [2392 rows x 6 columns]

# %%
sns.heatmap(data.corr(),cmap="YlGnBu", annot=True)
plt.show()
